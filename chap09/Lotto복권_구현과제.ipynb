# %%
import random

# 6개 번호만 발행
def generate_lotto_ticket():
    return sorted(random.sample(range(1, 46), 6))

# 당첨번호(6개) + 보너스번호(중복 제외)
def generate_winning_numbers():
    temp = list(random.sample(range(1,46), 7))
    main = sorted(temp[:-1])
    bonus = temp[-1]
    return main, bonus

# 당첨 판별
def check_winning_rank(ticket, winning_main, bonus):
    numOfMatch = len(set(ticket) & set(winning_main))
    isBonus = bonus in ticket
    result = ""
        
    if numOfMatch == 6:
        result = "1등"
    elif numOfMatch == 5 and isBonus == True:
        result = "2등"
    elif numOfMatch == 5:
        result = "3등"
    elif numOfMatch == 4:
        result = "4등"
    elif numOfMatch == 3:
        result = "5등"
    else :
        result = "꽝"

    return result

# 시뮬레이션 실행
def run_lotto_simulation(n):
    winning_main, bonus = generate_winning_numbers()
    print("■ 당첨 번호:", winning_main, "+ 보너스:", bonus)
    
    results = {"1등":0, "2등":0, "3등":0, "4등":0, "5등":0, "꽝":0}
    
    for i in range(n):
        ticket = generate_lotto_ticket()
        rank = check_winning_rank(ticket, winning_main, bonus)
        results[rank] += 1
        print(f"{i+1}번 복권: {ticket} → {rank}")
    
    print("\n📊 최종 당첨 통계:")
    for k, v in results.items():
        print(f"{k}: {v}장 ({v/n*100:.2f}%)")

# 실행 예시
# 스크립트 실행 진입점을 정의
if __name__ == "__main__": # 현재 파일이 직접 실행되는 경우에만 아래 내용을 실행하라는 의미
    try:
        count = int(input("발행할 로또 복권 개수 입력: "))
        run_lotto_simulation(count)
    except:
        print("올바른 숫자를 입력하세요.")
# Out:
# ■ 당첨 번호: [9, 17, 22, 38, 40, 44] + 보너스: 23
# 1번 복권: [4, 9, 27, 37, 41, 42] → 꽝
# 2번 복권: [5, 16, 29, 30, 32, 44] → 꽝
# 3번 복권: [19, 21, 22, 31, 37, 42] → 꽝
# 4번 복권: [8, 12, 23, 26, 28, 29] → 꽝
# 5번 복권: [3, 26, 27, 33, 39, 42] → 꽝
# 6번 복권: [9, 17, 22, 26, 37, 43] → 5등
# 7번 복권: [12, 17, 23, 33, 39, 42] → 꽝
# 8번 복권: [8, 18, 24, 36, 37, 40] → 꽝
# 9번 복권: [1, 15, 20, 25, 28, 31] → 꽝
# 10번 복권: [24, 33, 36, 40, 44, 45] → 꽝
# 11번 복권: [11, 12, 27, 36, 40, 42] → 꽝
# 12번 복권: [10, 12, 21, 30, 35, 43] → 꽝
# 13번 복권: [3, 5, 31, 33, 41, 43] → 꽝
# 14번 복권: [9, 15, 18, 29, 40, 41] → 꽝
# 15번 복권: [7, 15, 16, 27, 28, 29] → 꽝
# 16번 복권: [3, 15, 34, 41, 42, 43] → 꽝
# 17번 복권: [1, 2, 9, 11, 19, 31] → 꽝
# 18번 복권: [8, 14, 22, 24, 30, 44] → 꽝
# 19번 복권: [4, 20, 21, 26, 31, 40] → 꽝
# 20번 복권: [1, 3, 4, 32, 39, 40] → 꽝
# 21번 복권: [5, 6, 19, 39, 43, 45] → 꽝
# 22번 복권: [2, 13, 22, 31, 35, 38] → 꽝
# 23번 복권: [2, 4, 21, 29, 32, 43] → 꽝
# 24번 복권: [10, 14, 15, 22, 26, 34] → 꽝
# 25번 복권: [1, 17, 32, 35, 37, 42] → 꽝
# 26번 복권: [6, 10, 12, 22, 34, 43] → 꽝
# 27번 복권: [5, 18, 27, 34, 38, 45] → 꽝
# 28번 복권: [10, 17, 23, 24, 31, 33] → 꽝
# 29번 복권: [16, 23, 24, 30, 36, 39] → 꽝
# 30번 복권: [2, 9, 14, 19, 21, 31] → 꽝
# 31번 복권: [4, 9, 13, 19, 31, 33] → 꽝
# 32번 복권: [5, 21, 22, 33, 36, 44] → 꽝
# 33번 복권: [1, 7, 10, 13, 15, 28] → 꽝
# 34번 복권: [11, 15, 29, 33, 40, 41] → 꽝
# 35번 복권: [4, 19, 30, 39, 42, 45] → 꽝
# 36번 복권: [18, 25, 29, 31, 33, 40] → 꽝
# 37번 복권: [5, 11, 27, 28, 33, 38] → 꽝
# 38번 복권: [6, 14, 18, 20, 34, 37] → 꽝
# 39번 복권: [4, 15, 21, 23, 35, 44] → 꽝
# 40번 복권: [2, 5, 17, 27, 32, 36] → 꽝
# 41번 복권: [5, 14, 23, 35, 43, 45] → 꽝
# 42번 복권: [22, 28, 30, 34, 39, 43] → 꽝
# 43번 복권: [4, 7, 10, 19, 21, 37] → 꽝
# 44번 복권: [18, 28, 31, 33, 38, 39] → 꽝
# 45번 복권: [5, 9, 24, 35, 38, 40] → 5등
# 46번 복권: [4, 6, 18, 19, 23, 37] → 꽝
# 47번 복권: [18, 19, 29, 34, 35, 39] → 꽝
# 48번 복권: [5, 15, 23, 32, 34, 40] → 꽝
# 49번 복권: [4, 23, 33, 38, 39, 44] → 꽝
# 50번 복권: [2, 5, 11, 18, 33, 40] → 꽝
# 51번 복권: [4, 21, 24, 34, 35, 42] → 꽝
# 52번 복권: [2, 3, 15, 22, 23, 31] → 꽝
# 53번 복권: [1, 12, 14, 24, 33, 40] → 꽝
# 54번 복권: [3, 7, 12, 23, 35, 40] → 꽝
# 55번 복권: [10, 15, 17, 18, 37, 40] → 꽝
# 56번 복권: [11, 12, 17, 36, 43, 44] → 꽝
# 57번 복권: [2, 21, 22, 25, 30, 36] → 꽝
# 58번 복권: [2, 9, 16, 31, 38, 44] → 5등
# 59번 복권: [1, 21, 25, 26, 33, 37] → 꽝
# 60번 복권: [19, 20, 31, 34, 37, 41] → 꽝
# 61번 복권: [3, 11, 22, 30, 33, 35] → 꽝
# 62번 복권: [8, 10, 13, 16, 21, 28] → 꽝
# 63번 복권: [6, 12, 23, 27, 29, 31] → 꽝
# 64번 복권: [4, 6, 15, 34, 39, 41] → 꽝
# 65번 복권: [3, 6, 25, 26, 27, 45] → 꽝
# 66번 복권: [14, 15, 19, 21, 39, 40] → 꽝
# 67번 복권: [1, 11, 17, 20, 33, 44] → 꽝
# 68번 복권: [7, 18, 21, 33, 39, 45] → 꽝
# 69번 복권: [9, 11, 14, 16, 22, 25] → 꽝
# 70번 복권: [3, 12, 13, 16, 31, 36] → 꽝
# 71번 복권: [13, 15, 17, 22, 35, 40] → 5등
# 72번 복권: [14, 15, 18, 21, 29, 34] → 꽝
# 73번 복권: [14, 20, 21, 33, 36, 37] → 꽝
# 74번 복권: [2, 25, 28, 31, 35, 45] → 꽝
# 75번 복권: [5, 10, 17, 29, 41, 45] → 꽝
# 76번 복권: [3, 18, 28, 33, 34, 38] → 꽝
# 77번 복권: [7, 15, 20, 31, 38, 43] → 꽝
# 78번 복권: [3, 11, 26, 27, 29, 39] → 꽝
# 79번 복권: [6, 15, 16, 31, 34, 39] → 꽝
# 80번 복권: [7, 14, 18, 25, 27, 33] → 꽝
# 81번 복권: [1, 11, 22, 26, 39, 43] → 꽝
# 82번 복권: [4, 16, 26, 33, 36, 41] → 꽝
# 83번 복권: [7, 21, 22, 23, 29, 44] → 꽝
# 84번 복권: [2, 5, 8, 15, 26, 36] → 꽝
# 85번 복권: [4, 6, 18, 19, 26, 36] → 꽝
# 86번 복권: [4, 6, 30, 31, 39, 43] → 꽝
# 87번 복권: [13, 22, 25, 37, 41, 44] → 꽝
# 88번 복권: [17, 21, 26, 27, 32, 44] → 꽝
# 89번 복권: [19, 20, 30, 36, 43, 44] → 꽝
# 90번 복권: [14, 23, 26, 35, 36, 37] → 꽝
# 91번 복권: [14, 17, 19, 26, 30, 37] → 꽝
# 92번 복권: [8, 9, 10, 16, 39, 42] → 꽝
# 93번 복권: [4, 9, 15, 29, 37, 43] → 꽝
# 94번 복권: [6, 14, 15, 24, 34, 38] → 꽝
# 95번 복권: [4, 13, 25, 26, 30, 37] → 꽝
# 96번 복권: [12, 15, 24, 34, 38, 39] → 꽝
# 97번 복권: [14, 31, 41, 42, 43, 44] → 꽝
# 98번 복권: [13, 15, 16, 18, 21, 32] → 꽝
# 99번 복권: [3, 5, 6, 21, 40, 43] → 꽝
# 100번 복권: [8, 17, 20, 28, 41, 45] → 꽝
#
# 📊 최종 당첨 통계:
# 1등: 0장 (0.00%)
# 2등: 0장 (0.00%)
# 3등: 0장 (0.00%)
# 4등: 0장 (0.00%)
# 5등: 4장 (4.00%)
# 꽝: 96장 (96.00%)
