# %% [markdown]
# 파이썬함수 > zip(), map() 함수 공부하기

# %%
list1 = [1, 2, 3]
list2 = ['a', 'b', 'c']

zipped = zip(list1, list2)# 짝을 tuple로 만드는 iterator 객체를 준다
result = list(zipped)

print(result)  # [(1, 'a'), (2, 'b'), (3, 'c')]
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %% [markdown]
# *zipped	리스트 내부 요소들을 하나씩 풀어서 전달
#
# zip(*zipped)	튜플 요소별로 다시 묶기 (역변환)

# %%
zipped = [(1, 'a'), (2, 'b'), (3, 'c')]
unzipped = zip(*zipped) ## 변수 unzipped는 iterator 객체이다 >> 2개의 iterable tuple로 구성됨
### *zipped는 unpack하는 것으로(1,2,3), ('a','b','c')으로 나눈다::(1,'a')을 unpack하면 1, 'a'로 나눈다
### zip(*zipped)는 (1,2,3) 형태로 모은다 
list1, list2 = map(list, unzipped)
print(list1)  # [1, 2, 3]
print(list2)  # ['a', 'b', 'c']
# Out:
# [1, 2, 3]
# ['a', 'b', 'c']

# %%
zipped = [(1, 'a'), (2, 'b'), (3, 'c')]
numbers, names = zip(*zipped)

for num, name in zip(numbers, names):
    print(f"num={num}, name= {name}")
# Out:
# num=1, name= a
# num=2, name= b
# num=3, name= c

# %%
def square(x):
    return x ** 2

numbers = [1, 2, 3, 4]
squared = map(square, numbers)
# 리스트 numbers의 각 요소에 대해 square 함수를 적용한 결과를 하나씩 생성하는 반복 가능한 객체(iterator)를 만든다

print(list(squared))  # [1, 4, 9, 16]

# %%
data = ['apple', 'banana', 'kiwi', 'grape']

# 문자열 길이순 정렬
data.sort(key=lambda x: len(x)) # key는 정렬 기준으로 람다식으로 한다는 말
# lambda x의 x는 data 리스트의 각 요소(멤버)**를 의미
print(data)  # ['kiwi', 'apple', 'grape', 'banana']

# %%
numbers = [1, 2, 3, 4]
squared = map(lambda x: x ** 2, numbers)
# x는 언제나 "어떤 컬렉션의 한 원소"를 의미
#  lambda 함수는 리스트 등의 컬렉션을 순회할 때, 하나씩 꺼낸 요소가 x이다 

print(list(squared))  # [1, 4, 9, 16]

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]

result = map(lambda x, y: x + y, list1, list2)
print(list(result))  # [5, 7, 9]

# %%
nums = [1, 2, 3, 4, 5, 6]
evens = list(filter(lambda x: x % 2 == 0, nums))
# filter() 함수는 if 문처럼 조건을 만족하는 요소만 걸러내는 기능
print(evens)  # [2, 4, 6]

# %% [markdown]
# filter(function, iterable)
# - iterable의 요소들을 하나씩 function에 넣어
#
# - function(x)가 True인 요소만 남겨서 새로운 이터레이터로 반환

# %%
from functools import reduce

nums = [1, 2, 3, 4]
product = reduce(lambda x, y: x * y, nums) # reduce()는 리스트 전체를 하나의 값으로 누적(accumulate)
# (((1 * 2) * 3) * 4) = 24
print(product)  # 24

# %% [markdown]
# ## 람다식의 특징
#
# - 간결성> 작은 함수를 한 줄로 표현 가능
# - 익명성> 함수 이름 없이 사용 가능
# - 일회성 사용> 다른 함수(map, filter 등)의 인자로 자주 사용
# - 단점> 복잡한 로직에는 부적합 (가독성 떨어짐)

# %% [markdown]
# ## 고차 함수(high-order function) 또는 콜백(callback) 개념
#
# - 함수를 다른 함수의 인수(argument) 전달
#
# - 함수를 변수에 저장
#
# - 함수를 인자로 전달
#
# - 함수의 반환값으로 또 다른 함수를 반환

# %%
def ten_times(func):
    for i in range(5):
        func()
        
def print_hello():
    print("hello")
    
ten_times(print_hello)
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
def add(x,y):
    return x+y

def apply_operation(operation, x, y):
    return operation(x,y)

result = apply_operation(add,3,4)
print(f"result={result}")
# Out:
# result=7

# %%
def power(item):
    return item**2

def under_three(item):
    return item <3

lst=[1,2,3,4,5]
map_list = map(power, lst)
print(list(map_list))

filter_list = filter(under_three, lst)
print(list(filter_list))
# Out:
# [1, 4, 9, 16, 25]
# [1, 2]

# %%
#def power(item):
#    return item**2
power = lambda x: x*x

#def under_three(item):
#    return item <3
under_three = lambda x: x<3

lst=[1,2,3,4,5]
map_list = map(power, lst)
print(list(map_list))

filter_list = filter(under_three, lst)
print(list(filter_list))
# Out:
# [1, 4, 9, 16, 25]
# [1, 2]

# %%
# %pip install torch
# Out:
# Collecting torch
#   Downloading torch-2.9.1-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\user\miniconda3\lib\site-packages (from torch) (4.15.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in c:\users\user\miniconda3\lib\site-packages (from torch) (80.9.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading markupsafe-3.0.3-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Downloading torch-2.9.1-cp313-cp313-win_amd64.whl (110.9 MB)
#    ---------------------------------------- 0.0/110.9 MB ? eta -:--:--
#    ---------------------------------------- 1.0/110.9 MB 6.2 MB/s eta 0:00:18
#     --------------------------------------- 2.1/110.9 MB 5.7 MB/s eta 0:00:20
#    - -------------------------------------- 3.1/110.9 MB 5.5 MB/s eta 0:00:20
#    - -------------------------------------- 4.2/110.9 MB 5.4 MB/s eta 0:00:20
#    - -------------------------------------- 5.2/110.9 MB 5.4 MB/s eta 0:00:20
#    -- ------------------------------------- 6.3/110.9 MB 5.2 MB/s eta 0:00:21
#    -- ------------------------------------- 7.1/110.9 MB 5.1 MB/s eta 0:00:21
#    -- ------------------------------------- 7.9/110.9 MB 4.8 MB/s eta 0:00:22
#    --- ------------------------------------ 8.4/110.9 MB 4.6 MB/s eta 0:00:23
#    --- ------------------------------------ 9.2/110.9 MB 4.5 MB/s eta 0:00:23
#    --- ------------------------------------ 9.7/110.9 MB 4.4 MB/s eta 0:00:24
#    --- ------------------------------------ 10.5/110.9 MB 4.3 MB/s eta 0:00:24
#    ---- ----------------------------------- 11.3/110.9 MB 4.2 MB/s eta 0:00:24
#    ------------ --------------------------- 34.9/110.9 MB 3.4 MB/s eta 0:00:23
#    ------------ --------------------------- 35.7/110.9 MB 3.4 MB/s eta 0:00:23
#    ------------- -------------------------- 36.2/110.9 MB 3.4 MB/s eta 0:00:23
#    ------------- -------------------------- 36.7/110.9 MB 3.4 MB/s eta 0:00:23
#    ------------- -------------------------- 37.2/110.9 MB 3.4 MB/s eta 0:00:22
#    ------------- -------------------------- 38.0/110.9 MB 3.3 MB/s eta 0:00:22
#    ------------- -------------------------- 38.5/110.9 MB 3.3 MB/s eta 0:00:22
#    -------------- ------------------------- 39.1/110.9 MB 3.3 MB/s eta 0:00:22
#    -------------- ------------------------- 39.8/110.9 MB 3.3 MB/s eta 0:00:22
#    -------------- ------------------------- 40.4/110.9 MB 3.3 MB/s eta 0:00:22
#    -------------- ------------------------- 40.9/110.9 MB 3.3 MB/s eta 0:00:22
#    -------------- ------------------------- 41.4/110.9 MB 3.3 MB/s eta 0:00:22
#    --------------- ------------------------ 41.9/110.9 MB 3.3 MB/s eta 0:00:22
#    --------------- ------------------------ 42.2/110.9 MB 3.2 MB/s eta 0:00:22
#    --------------- ------------------------ 42.5/110.9 MB 3.2 MB/s eta 0:00:22
#    --------------- ------------------------ 43.0/110.9 MB 3.2 MB/s eta 0:00:22
#    --------------- ------------------------ 43.5/110.9 MB 3.2 MB/s eta 0:00:22
#    --------------- ------------------------ 43.8/110.9 MB 3.1 MB/s eta 0:00:22
#    --------------- ------------------------ 44.0/110.9 MB 3.1 MB/s eta 0:00:22
#    ---------------- ----------------------- 44.6/110.9 MB 3.1 MB/s eta 0:00:22
#    ---------------- ----------------------- 44.8/110.9 MB 3.1 MB/s eta 0:00:22
#    ---------------- ----------------------- 45.1/110.9 MB 3.1 MB/s eta 0:00:22
#    ---------------- ----------------------- 45.6/110.9 MB 3.0 MB/s eta 0:00:22
#    ---------------- ----------------------- 46.1/110.9 MB 3.0 MB/s eta 0:00:22
#    ---------------- ----------------------- 46.7/110.9 MB 3.0 MB/s eta 0:00:22
#    ----------------- ---------------------- 47.2/110.9 MB 3.0 MB/s eta 0:00:22
#    ----------------- ---------------------- 47.7/110.9 MB 3.0 MB/s eta 0:00:22
#    ----------------- ---------------------- 48.2/110.9 MB 3.0 MB/s eta 0:00:21
#    ----------------- ---------------------- 49.0/110.9 MB 3.0 MB/s eta 0:00:21
#    ----------------- ---------------------- 49.5/110.9 MB 3.0 MB/s eta 0:00:21
#    ------------------ --------------------- 50.1/110.9 MB 3.0 MB/s eta 0:00:21
#    ------------------ --------------------- 50.6/110.9 MB 3.0 MB/s eta 0:00:21
#    ------------------ --------------------- 51.1/110.9 MB 3.0 MB/s eta 0:00:21
#    ------------------ --------------------- 51.9/110.9 MB 3.0 MB/s eta 0:00:20
#    ------------------ --------------------- 52.2/110.9 MB 3.0 MB/s eta 0:00:20
#    ------------------------ --------------- 67.6/110.9 MB 2.7 MB/s eta 0:00:17
#    ------------------------ --------------- 68.2/110.9 MB 2.7 MB/s eta 0:00:16
#    ------------------------ --------------- 68.7/110.9 MB 2.7 MB/s eta 0:00:16
#    ------------------------ --------------- 69.2/110.9 MB 2.7 MB/s eta 0:00:16
#    ------------------------- -------------- 69.7/110.9 MB 2.7 MB/s eta 0:00:16
#    ------------------------- -------------- 70.5/110.9 MB 2.7 MB/s eta 0:00:16
#    ------------------------- -------------- 71.0/110.9 MB 2.7 MB/s eta 0:00:15
#    ------------------------- -------------- 71.3/110.9 MB 2.7 MB/s eta 0:00:15
#    ------------------------- -------------- 71.8/110.9 MB 2.7 MB/s eta 0:00:15
#    -------------------------- ------------- 72.4/110.9 MB 2.7 MB/s eta 0:00:15
#    -------------------------- ------------- 72.6/110.9 MB 2.7 MB/s eta 0:00:15
#    -------------------------- ------------- 73.1/110.9 MB 2.7 MB/s eta 0:00:15
#    -------------------------- ------------- 73.1/110.9 MB 2.7 MB/s eta 0:00:15
#    -------------------------- ------------- 73.7/110.9 MB 2.6 MB/s eta 0:00:15
#    -------------------------- ------------- 73.9/110.9 MB 2.6 MB/s eta 0:00:15
#    -------------------------- ------------- 74.4/110.9 MB 2.6 MB/s eta 0:00:14
#    -------------------------- ------------- 74.7/110.9 MB 2.6 MB/s eta 0:00:14
#    --------------------------- ------------ 75.0/110.9 MB 2.6 MB/s eta 0:00:14
#    --------------------------- ------------ 75.2/110.9 MB 2.6 MB/s eta 0:00:14
#    --------------------------- ------------ 75.8/110.9 MB 2.6 MB/s eta 0:00:14
#    --------------------------- ------------ 76.0/110.9 MB 2.6 MB/s eta 0:00:14
#    --------------------------- ------------ 76.3/110.9 MB 2.6 MB/s eta 0:00:14
#    --------------------------- ------------ 76.5/110.9 MB 2.6 MB/s eta 0:00:14
#    --------------------------- ------------ 76.8/110.9 MB 2.6 MB/s eta 0:00:14
#    --------------------------- ------------ 77.1/110.9 MB 2.5 MB/s eta 0:00:14
#    --------------------------- ------------ 77.6/110.9 MB 2.5 MB/s eta 0:00:14
#    ---------------------------- ----------- 77.9/110.9 MB 2.5 MB/s eta 0:00:14
#    ---------------------------- ----------- 78.4/110.9 MB 2.4 MB/s eta 0:00:14
#    ---------------------------- ----------- 78.6/110.9 MB 2.4 MB/s eta 0:00:14
#    ---------------------------- ----------- 79.2/110.9 MB 2.4 MB/s eta 0:00:14
#    ---------------------------- ----------- 79.7/110.9 MB 2.4 MB/s eta 0:00:14
#    ---------------------------- ----------- 80.0/110.9 MB 2.4 MB/s eta 0:00:13
#    ----------------------------- ---------- 80.5/110.9 MB 2.4 MB/s eta 0:00:13
#    ----------------------------- ---------- 80.7/110.9 MB 2.4 MB/s eta 0:00:13
#    ----------------------------- ---------- 81.0/110.9 MB 2.4 MB/s eta 0:00:13
#    ---------------------------------- ----- 94.9/110.9 MB 2.0 MB/s eta 0:00:09
#    ---------------------------------- ----- 95.2/110.9 MB 2.0 MB/s eta 0:00:08
#    ---------------------------------- ----- 95.4/110.9 MB 2.0 MB/s eta 0:00:08
#    ---------------------------------- ----- 95.7/110.9 MB 2.0 MB/s eta 0:00:08
#    ---------------------------------- ----- 96.2/110.9 MB 2.0 MB/s eta 0:00:08
#    ---------------------------------- ----- 96.7/110.9 MB 2.0 MB/s eta 0:00:08
#    ---------------------------------- ----- 97.0/110.9 MB 2.0 MB/s eta 0:00:08
#    ----------------------------------- ---- 97.3/110.9 MB 1.9 MB/s eta 0:00:08
#    ----------------------------------- ---- 97.5/110.9 MB 1.9 MB/s eta 0:00:07
#    ----------------------------------- ---- 98.0/110.9 MB 1.9 MB/s eta 0:00:07
#    ----------------------------------- ---- 98.3/110.9 MB 1.9 MB/s eta 0:00:07
#    ----------------------------------- ---- 98.6/110.9 MB 1.9 MB/s eta 0:00:07
#    ----------------------------------- ---- 98.8/110.9 MB 1.9 MB/s eta 0:00:07
#    ----------------------------------- ---- 99.1/110.9 MB 1.9 MB/s eta 0:00:07
#    ----------------------------------- ---- 99.4/110.9 MB 1.9 MB/s eta 0:00:07
#    ----------------------------------- ---- 99.6/110.9 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 99.9/110.9 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 100.1/110.9 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 100.4/110.9 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 100.7/110.9 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 100.9/110.9 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 101.2/110.9 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 101.2/110.9 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 101.4/110.9 MB 1.9 MB/s eta 0:00:06
#    ------------------------------------ --- 101.7/110.9 MB 1.8 MB/s eta 0:00:05
#    ------------------------------------ --- 102.0/110.9 MB 1.8 MB/s eta 0:00:05
#    ------------------------------------ --- 102.2/110.9 MB 1.8 MB/s eta 0:00:05
#    ------------------------------------ --- 102.5/110.9 MB 1.8 MB/s eta 0:00:05
#    ------------------------------------- -- 103.0/110.9 MB 1.8 MB/s eta 0:00:05
#    ------------------------------------- -- 103.5/110.9 MB 1.8 MB/s eta 0:00:05
#    ------------------------------------- -- 103.8/110.9 MB 1.8 MB/s eta 0:00:04
#    ------------------------------------- -- 104.3/110.9 MB 1.8 MB/s eta 0:00:04
#    ------------------------------------- -- 104.9/110.9 MB 1.8 MB/s eta 0:00:04
#    ------------------------------------- -- 105.1/110.9 MB 1.8 MB/s eta 0:00:04
#    ------------------------------------- -- 105.4/110.9 MB 1.8 MB/s eta 0:00:04
#    -------------------------------------- - 105.6/110.9 MB 1.8 MB/s eta 0:00:03
#    -------------------------------------- - 105.9/110.9 MB 1.8 MB/s eta 0:00:03
#    -------------------------------------- - 106.2/110.9 MB 1.8 MB/s eta 0:00:03
#    -------------------------------------- - 106.4/110.9 MB 1.7 MB/s eta 0:00:03
#    -------------------------------------- - 106.7/110.9 MB 1.7 MB/s eta 0:00:03
#    -------------------------------------- - 107.0/110.9 MB 1.7 MB/s eta 0:00:03
#    -------------------------------------- - 107.2/110.9 MB 1.7 MB/s eta 0:00:03
#    -------------------------------------- - 107.5/110.9 MB 1.7 MB/s eta 0:00:03
#    -------------------------------------- - 107.7/110.9 MB 1.7 MB/s eta 0:00:02
#    -------------------------------------- - 108.0/110.9 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------------  108.3/110.9 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------------  108.5/110.9 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------------  108.5/110.9 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------------  108.8/110.9 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------------  109.1/110.9 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------------  109.3/110.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  109.6/110.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  109.8/110.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  110.1/110.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  110.4/110.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  110.6/110.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  110.6/110.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  110.9/110.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 110.9/110.9 MB 1.6 MB/s  0:00:52
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.7 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.0 MB 1.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 1.4 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.6 MB/s  0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/6.3 MB 1.9 MB/s eta 0:00:03
#    ------ --------------------------------- 1.0/6.3 MB 1.9 MB/s eta 0:00:03
#    --------- ------------------------------ 1.6/6.3 MB 1.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.8/6.3 MB 1.8 MB/s eta 0:00:03
#    ------------- -------------------------- 2.1/6.3 MB 1.7 MB/s eta 0:00:03
#    -------------- ------------------------- 2.4/6.3 MB 1.7 MB/s eta 0:00:03
#    ------------------ --------------------- 2.9/6.3 MB 1.7 MB/s eta 0:00:02
#    ------------------- -------------------- 3.1/6.3 MB 1.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.7/6.3 MB 1.8 MB/s eta 0:00:02
#    ------------------------ --------------- 3.9/6.3 MB 1.7 MB/s eta 0:00:02
#    ------------------------ --------------- 3.9/6.3 MB 1.7 MB/s eta 0:00:02
#    -------------------------- ------------- 4.2/6.3 MB 1.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.5/6.3 MB 1.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 4.7/6.3 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 5.2/6.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 5.8/6.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 1.5 MB/s  0:00:04
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 1.5 MB/s  0:00:00
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp313-cp313-win_amd64.whl (15 kB)
# Installing collected packages: mpmath, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch
#
#    ---------------------------------------- 0/8 [mpmath]
#    ---------------------------------------- 0/8 [mpmath]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ----- ---------------------------------- 1/8 [sympy]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    ---------- ----------------------------- 2/8 [networkx]
#    -------------------- ------------------- 4/8 [fsspec]
#    -------------------- ------------------- 4/8 [fsspec]
#    ------------------------------ --------- 6/8 [jinja2]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ----------------------------------- ---- 7/8 [torch]
#    ---------------------------------------- 8/8 [torch]
#
# Successfully installed MarkupSafe-3.0.3 filelock-3.20.0 fsspec-2025.10.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 sympy-1.14.0 torch-2.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
USE_CUDA = torch.cuda.is_available()
device = torch.device('cuda:0' if USE_CUDA else 'cpu')
print('cuda 사용: ', USE_CUDA)
print('현재 사용 device', device)
print('CUDA Index: ', torch.cuda.current_device())
print('CUDA device:', torch.cuda.get_device_name(0) if USE_CUDA else 'No GPU available')
print('GPU 개수:', torch.cuda.device_count())
# Out:
# cuda 사용:  False
# 현재 사용 device cpu
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 6
#       4 print('cuda 사용: ', USE_CUDA)
#       5 print('현재 사용 device', device)
# ----> 6 print('CUDA Index: ', torch.cuda.current_device())
#       7 print('CUDA device:', torch.cuda.get_device_name(0) if USE_CUDA else 'No GPU available')
#       8 print('GPU 개수:', torch.cuda.device_count())
#
# File c:\Users\user\miniconda3\Lib\site-packages\torch\cuda\__init__.py:1069, in current_device()
#    1067 def current_device() -> int:
#    1068     r"""Return the index of a currently selected device."""
# -> 1069     _lazy_init()
#    1070     return torch._C._cuda_getDevice()
#
# File c:\Users\user\miniconda3\Lib\site-packages\torch\cuda\__init__.py:403, in _lazy_init()
#     398     raise RuntimeError(
#     399         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     400         "multiprocessing, you must use the 'spawn' start method"
#     401     )
#     402 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 403     raise AssertionError("Torch not compiled with CUDA enabled")
#     404 if _cudart is None:
#     405     raise AssertionError(
#     406         "libcudart functions unavailable. It looks like you have a broken build?"
#     407     )
#
# AssertionError: Torch not compiled with CUDA enabled
