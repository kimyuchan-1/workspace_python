# %%
"""min_max2모듈의 min_max2함수 호출하기"""

import min_max2 # min_max2.py 코드를 가져오는 것 -> 코드 전체를 가져와서 기존 코드 이외의 코드까지 실행됨

x = float(input('실수 x：'))
y = float(input('실수 y：'))

mini, maxi = min_max2.min_max2(x, y)
print('최솟값은', mini, '입니다.')
print('최댓값은', maxi, '입니다.')
# Out:
# 최솟값은 4 이고 최댓값은 5 입니다.
# 최솟값은 1.58 입니다.
# 최댓값은 42.4 입니다.

# %%
"""min_max 모듈의 함수 호출하기"""

import min_max

x = float(input('실수 x：'))
y = float(input('실수 y：'))
z = float(input('실수 z：'))

print('x와 y의 최솟값은 {}이고, 최댓값은 {}입니다.'.format(*min_max.min_max2(x, y)))
print('y와 z의 최솟값은 {}이고, 최댓값은 {}입니다.'.format(*min_max.min_max2(y, z)))
print('x와 z의 최솟값은 {}이고, 최댓값은 {}입니다.'.format(*min_max.min_max2(x, z)))
print('x, y, z의 최솟값은 {}이고, 최댓값은 {}입니다.'.format(*min_max.min_max3(x, y, z)))
# Out:
# x와 y의 최솟값은 4.5이고, 최댓값은 137.0입니다.
# y와 z의 최솟값은 137.0이고, 최댓값은 245.21입니다.
# x와 z의 최솟값은 4.5이고, 최댓값은 245.21입니다.
# x, y, z의 최솟값은 4.5이고, 최댓값은 245.21입니다.

# %%
import sys

print(sys.path)
# Out:
# ['c:\\Users\\user\\miniconda3\\python313.zip', 'c:\\Users\\user\\miniconda3\\DLLs', 'c:\\Users\\user\\miniconda3\\Lib', 'c:\\Users\\user\\miniconda3', '', 'c:\\Users\\user\\miniconda3\\Lib\\site-packages', 'c:\\Users\\user\\miniconda3\\Lib\\site-packages\\win32', 'c:\\Users\\user\\miniconda3\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\user\\miniconda3\\Lib\\site-packages\\Pythonwin']

# %%
# FQN(Fully Qualified Name)

import min_max
import min_max2

print(f'{min_max.min_max2(4.5,324.6)}')
print(f'{min_max2.min_max2(4.5,324.6)}')
# Out:
# (4.5, 324.6)
# (4.5, 324.6)

# %%
# import 문

import numpy as np # as 뒤 별칭
np.array() # 함수 호출 시 별칭.함수

from min_max import min_max2 # 모듈 전체 중 특정 함수만 사용 -> 모듈 이름 없이도 함수 호출 가능

from min_max import * # 특정 모듈에서 _로 시작하는 이름을 제외한 함수 모두 사용

# %%
# 모듈 여러 개를 모은 폴더(모듈을 디렉터리화): 패키지

# 모듈들(.py) + __init.py__
