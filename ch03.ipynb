# %%
a = 3
if a < 5:
    print("hahaha")
# Out:
# hahaha

# %%
a = 0
if a:
    print("hahaha")

# %%
a = None
if a:
    print("hahaha")

# %%
a = 3.13
a += 0.01
print(a == 3.14)

e = 1e-8
abs(a - 3.14) < e
# Out:
# False
# True

# %%
s1 = str('hello')
s2 = str('hello')

s1 == s2
# Out:
# True

# %%
d1 = [1, 2, 3]
d2 = [1, 2, 3]

d1 == d2
# Out:
# True

# %%
id(d1) == id(d2)
# Out:
# False

# %%
s = 'hello'

'h' in s
# Out:
# True

# %%
d = [1, 2, 3]

3 in d, 4 in d
# Out:
# (True, False)

# %%
if a < 5:
    pass
elif a > 5:
    pass
else:
    pass

# %%
a=3
if a<5: print("hahaha")
# Out:
# hahaha

# %%
b = "OK" if a < 5 else "NO"

# %%
data = [1,2,3,4,5]
[d for d in data if d % 2 == 0]
# Out:
# [2, 4]

# %%
data = [2, 1, 3]
print(data)
print(sorted(data))
print(sorted(data, reverse=True))
print(data)
data.sort()
print(data)
# Out:
# [2, 1, 3]
# [1, 2, 3]
# [3, 2, 1]
# [2, 1, 3]
# [1, 2, 3]

# %%
max(2,1,3)
# Out:
# 3

# %%
max(2,3)
# Out:
# 3

# %%
a=1
b=2
f'{a}, {b}'
# Out:
# '1, 2'
